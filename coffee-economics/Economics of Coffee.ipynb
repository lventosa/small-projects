# %% [markdown]
# # Economics of Coffee

# %% [markdown]
# Over 2.25 billion cups of coffee are consumed in the world daily. Approximately 90% of coffee production takes place in developing countries while consumption happens primarily in industrialized economies. And coffee is not only a beverage but also a commodity traded in financial markets. For all this reasons, coffee is a really interesting good to study from an economist perspective.

# %%
using CSV, DataFrames

# %%
data = CSV.read("PCOFFOTMUSDM.csv");
first(data, 6)
# Out:
# 6×2 DataFrame
# │ Row │ DATE       │ PCOFFOTMUSDM │
# │     │ Dates.Date │ Float64      │
# ├─────┼────────────┼──────────────┤
# │ 1   │ 1990-01-01 │ 75.83        │
# │ 2   │ 1990-02-01 │ 84.01        │
# │ 3   │ 1990-03-01 │ 93.96        │
# │ 4   │ 1990-04-01 │ 93.73        │
# │ 5   │ 1990-05-01 │ 92.02        │
# │ 6   │ 1990-06-01 │ 88.26        │

# %%
describe(data)[[:variable, :eltype, :nmissing]]
# Out:
# 2×3 DataFrame
# │ Row │ variable     │ eltype   │ nmissing │
# │     │ Symbol       │ DataType │ Nothing  │
# ├─────┼──────────────┼──────────┼──────────┤
# │ 1   │ DATE         │ Date     │          │
# │ 2   │ PCOFFOTMUSDM │ Float64  │          │
